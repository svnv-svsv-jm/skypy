# %%
# %load_ext autoreload
# %autoreload 2

# %%
from skypy.utils.nb import nb_init
import json, os
from loguru import logger

nb_init()
# Out:
# INFO | nb_init | Set current dir to sky-py
# INFO | nb_init | You are using Python 3.13.9 (main, Oct 14 2025, 13:52:31) [Clang 17.0.0 (clang-1700.4.4.1)]

# %%
from skypy.schemas import ZATrainerDataArray, ZATrainerData
from skypy.za import load_trainer_data

trdata: ZATrainerDataArray = load_trainer_data()

# %%
trainer: ZATrainerData = trdata.values[1]

# %%
trainer.tr_id
# Out:
# 'Ev_m01_0070'

# %%
trainer.model_dump(mode="json")
# Out:
# {'tr_id': 'Ev_m01_0070',
#  'tr_type': 4542322475595477710,
#  'tr_type_2': 4542322475595477710,
#  'za_rank': 'Null',
#  'money_rate': 12,
#  'meg_evolution': False,
#  'last_hand': False,
#  'ai_basic': True,
#  'ai_high': True,
#  'ai_expert': True,
#  'ai_double': False,
#  'ai_raid': False,
#  'ai_weak': False,
#  'ai_item': False,
#  'ai_change': True,
#  'view_horizontal_angle': 30.0,
#  'view_vertical_angle': 50.0,
#  'view_range': 17.0,
#  'hearing_range': 17.0,
#  'poke_1': {'dev_id': 'DEV_YANTYAMU',
#   'form_id': 0,
#   'sex': 'None',
#   'item': 'ITEMID_ORENNOMI',
#   'level': 4,
#   'ball_id': 'MONSUTAABOORU',
#   'seikaku': 'OTTORI',
#   'tokusei': 'SET_2',
#   'talent_value': {'HP': 0, 'ATK': 0, 'DEF': 0, 'SPA': 0, 'SPD': 0, 'SPE': 0},
#   'effort_value': {'HP': 0, 'ATK': 0, 'DEF': 0, 'SPA': 0, 'SPD': 0, 'SPE': 0},
#   'rare_type': 'NO_RARE',
#   'scale_value': 128,
#   'waza_1': {'waza_id': 'WAZA_TAIATARI', 'is_plus_waza': False},
# ...
